# %% [markdown]
# # My Jupyter Notebook on IBM Data Science Experience

# %% [markdown]
# __Otasowie Osifo__
# Software Engineer

# %% [markdown]
# _I am interested in Datascience because I wissh to be able to combine knowledge from different subject areas in order to tell usable stories with data._

# %% [markdown]
# ### The code below is used to compute the average of the numbers from 1 to the input number n

# %%
def average(n):
    sum = 0
    for nloc in range(1, n + 1):
        sum = sum + nloc
    print(float(sum / n))

average(10)
# Out:
# 5.5

# %% [markdown]
#  - Mercury
#  - Venus
#  - Earth
#  - Mars
#  - jupiter
#  - Saturn
#  - Uranus
#  - Neptune
#
#
# <img src="https://solarsystem.nasa.gov/system/resources/detail_files/17771_PIA21345-800w.jpg">
#
#
# 1. Mercury
# 1. Venus
# 1. Earth
# 1. Mars
# 1. jupiter
# 1. Saturn
# 1. Uranus
# 1. Neptune
#
# __[link text](https://solarsystem.nasa.gov/resources/17771/so-far-from-home/)__
# __[link text](https://www.space.com/16080-solar-system-planets.html)__
